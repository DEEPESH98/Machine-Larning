# %% [markdown]
# <a href="https://colab.research.google.com/github/DEEPESH98/Machine-Larning/blob/master/Basic_opencv1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
#import matplotlib.pyplot as plt
import numpy as np

# %%
print(cv2.__version__)
# Out:
# 3.4.3

# %%
# images reading
# 1 means image in same color channel --GRB PR RGB
# 0 means no color channel --BLACK & WHITE --- GRAY image 
# -1 manage image transparency  // ager transparent vali image ho to 
img=cv2.imread('ab.jpg',0)
img1=cv2.imread('ab.jpg',1)
img2=cv2.imread('ab.jpg',-1)

# %%
img
# Out:
# array([[161, 161, 161, ..., 130, 129, 203],
#        [161, 161, 161, ..., 130, 129, 203],
#        [161, 161, 161, ..., 131, 129, 203],
#        ...,
#        [155, 155, 155, ..., 133, 131, 207],
#        [155, 155, 155, ..., 133, 131, 207],
#        [155, 155, 155, ..., 133, 131, 207]], dtype=uint8)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
# hight ,width, Rgb ya bgi dono me se koi ek // black and whit hoga to 3 kii jaga 0 hoga

# %%
# to display image
cv2_imshow(img)
cv2_imshow(img1)
#plt.imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1500x600 at 0x7F1442221588>
# <PIL.Image.Image image mode=RGB size=1500x600 at 0x7F14421A5D68>

# %%
cv2_imshow(img[0:130,0:150])
# Out:
# <PIL.Image.Image image mode=L size=150x130 at 0x7F14421A5EB8>

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x600 at 0x7F1442221240>

# %%
# wait for window to close
cv2.waitKey(0) # mili/micro seconds
# Out:
# -1

# %%
# split into BGR

# %%
x,y,z = cv2.split(img1)

# %%
cv2_imshow(x)
cv2_imshow(y)
cv2_imshow(z)
# Out:
# <PIL.Image.Image image mode=L size=1500x600 at 0x7F14421A5FD0>
# <PIL.Image.Image image mode=L size=1500x600 at 0x7F14421A5F60>
# <PIL.Image.Image image mode=L size=1500x600 at 0x7F14421A5F28>
